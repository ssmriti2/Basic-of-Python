# %% [markdown]
# Conditions and Branching.
#
#
#
#
#
#
#
#
#
# if, elif, else keywords are used to accomplish conditions and branching in python.
#
#
#
#
#
#
# if case1:
#     perform action1
#
#
#
#
#
# elif case2:
#     perform action2
#
#
#
#
#
#
#
# else:
#     perform action3
#
#
#
#
#
# Different comparison operators shown below, can be used with if statements.
#
#
#
#
#
#
#
# Equals: a == b
#
#
#
#
#
# Not Equals: a != b
#
#
#
#
# Less than: a < b
#
#
#
#
#
# Less than or equal to: a <= b
#
#
#
#
#
#
# Greater than: a > b
#
#
#
#
#
#
# Greater than or equal to: a >= b
#
#
#
#
#
# if a > b:
#
#
#
#
#     print("a is greater than b")
#
#
#
#
#
#
# elif a == b:
#
#
#
#
#     print("a is equal to b")
#
#
#
#
#
#
#
#
# else:
#
#
#     print("a is less than b")

# %% [markdown]
# 1. if statement: How python program enters if blocks?
#
#
#
# Hint: when if conditions is True
#
#
#
#
# if True:
#   print("if block goes here")
#
#
#
#
#
# if False:
#   print("if block goes here")

# %%
# explain here


a=20
b=18

if a>b:
    print(f'Yes, The given condition is true.')
elif a==b:
    print("a and b are equal")
else:
    print('something else')
# Out:
# Yes, The given condition is true.

# %% [markdown]
# 2. Simple if else statements
#
#
#
# Generally, if statement has an optional elif, else clause.
#
#
#
#
# syntax 1
#
# if condition:
#     # block of code if condition is True
#
#
#
#
#
# else:
#     # block of code if condition is False
#
#
#
#
#
# syntax 2
#
# if condition1:
#     # code block 1
#
#
#
#
#
# elif condition2:
#     # code block 2
#
#
#
#
#
# else:
#     # code block 3

# %%
# Input number from user. print "postive number" if number is positive else print "negative number. Consider 0 as positive as well."

input_number=float(input("Enter the number:"))

if input_number>=0:
    print("Positive number")
else:
    print("Negative number")
# Out:
# Enter the number:90.0
# Positive number

# %% [markdown]
# #Input two numbers num1, and num2 from user,
#
# #if num1 > num2: print "num1 > num2"
# #if num1 == num2: print "num1 = num2"
# #if num1 < num2: print "num1 < num2"
#
# num1=input(

# %%
#Input two numbers num1, and num2 from user,

#if num1 > num2: print "num1 > num2" 



#if num1 == num2: print "num1 = num2" 

#if num1 < num2: print "num1 < num2"

num1=float(input('Enter the number1 :'))
num2=float(input("Enter the second number"))

if num1 > num2:
    print("num1 is greater than num2")
elif num1==num2:
    print("num1 is euqal to num2")
else:
    print('num1 < num2')
# Out:
# Enter the number1 :90
# Enter the second number89
# num1 is greater than num2

# %% [markdown]
# 3. Nested if else statements.
#
#
#
#
#
#
#
# if or else statements inside if or else statements.
#
#
#
#
#
#
# Syntax:
#
# if condition1:
#   if condition:
#     # code block
#   else:
#     # code block
#
#
#
#
#
#
#
# elif condition2:
#   if condition:
#     # code block
#   else:
#     # code block
#
# :::::::::::::::::
# :::::::::::::::::
#
# else:
#   if condition:
#     # code block
#
#   elif condition:
#     # code block
#   else:
#     # code block

# %%
# Write a python program to find max of three numbers.


num1=89
num2=90
num3=101

if num1>num3:
 if num1 >num2:
    print(f'The maximum number is {num1}')
 else:
     print(f'The maximun number is {num2}')
else:
 if num2>num3:
      print(f'The maximum numnber is{num2}' )
 else:
     print(f'The maximun nunber is {num3}')
# Out:
# The maximun nunber is 101

# %%
# Write a python program to find min of three numbers.

num1=50
num2=10
num3=40

if num1 <num2:
    if num1 < num3:
        print(f' The minimuin number is: {num1 }')
    else:
        print(f'The minimum number is: {num3 }' )
else:
    if num2 < num3:
        print(f'The minimum number is: {num2 }')
    else:
        print(f'the minimim number is: {num3 }')
# Out:
# The minimum number is: 10

# %% [markdown]
# 4. Short Hand if...else statements / Ternary Operators
#
#
#
# It is way of writing if else statement in a single line of code.
#
# Also, called Ternary operators.
#
#
#
#
#
# Syntax (simple if else)
#
# <if_block> if <condition> else <else_block>
#
# Syntax (nested simple if else)
#
#
#
#
# (<code_block> if <condition> else <code_block>) if < if_condition > else (<code_block> if <condition> else <code_block>)

# %%
#Write a python program to print max of 2 numbers using ternary operator.
a=20
b=60

print(f'The maximum number is {a}') if a > b else print(f'The maximum number is {b}')
# Out:
# The maximum number is 60

# %%
# Write a python program to print max of 3 numbers using ternary operator.

## write your program here
# max between three numbers

num1 = 2
num2 = 3
num3 = 4

(print(num1) if num1 > num3 else print(num3))if num1>num2 else (print(num2) if num2>num3 else print(num3))
# Out:
# 4

# %% [markdown]
# 5. Pass Keyword
#
#
#
# pass keyword acts as a placeholder for code to be added in if..else block.
#
# Use case
#
#
#
#
# consider case, when you want to determine your python code structure in advance before adding actual code.
# Syntax:
#
#
#
#
#
# if <condition>:
#
#
#
#   pass
#
#
#
#
# else <condition>:
#
#
#
#
#
#
#   pass

# %%
## write your program using "pass" keyword

a=34
b=56
if a>23:
  pass

else:
  pass
